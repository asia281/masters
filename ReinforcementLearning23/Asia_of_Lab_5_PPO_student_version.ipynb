# %% [markdown]
# <a href="https://colab.research.google.com/github/asia281/rl2023/blob/main/Asia_of_Lab_5_PPO_student_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://spinningup.openai.com/en/latest/algorithms/ppo.html

# %%
# After the installation is done please restart the colab kernel for it to pick up new packages
# No need to rerun this cell after kernel restart
# !apt-get install x11-utils > /dev/null 2>&1 
# !pip install pyglet > /dev/null 2>&1 
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install pyvirtualdisplay > /dev/null 2>&1
# !pip3 install swig

#!pip3 install box2d-py
#!pip3 install gym[Box_2D]
# !pip install -U colabgymrender
# !pip install neptune-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: swig in /usr/local/lib/python3.9/dist-packages (4.1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colabgymrender in /usr/local/lib/python3.9/dist-packages (1.1.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.9/dist-packages (from colabgymrender) (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.9/dist-packages (from moviepy->colabgymrender) (4.4.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from moviepy->colabgymrender) (2.27.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.9/dist-packages (from moviepy->colabgymrender) (2.25.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/dist-packages (from moviepy->colabgymrender) (1.22.4)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.9/dist-packages (from moviepy->colabgymrender) (0.1.10)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.9/dist-packages (from moviepy->colabgymrender) (4.65.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from moviepy->colabgymrender) (0.4.8)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.9/dist-packages (from imageio<3.0,>=2.5->moviepy->colabgymrender) (8.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (1.26.15)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: neptune-client in /usr/local/lib/python3.9/dist-packages (1.1.1)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (1.3.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (1.16.0)
# Requirement already satisfied: GitPython>=2.0.8 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (3.1.31)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (1.26.15)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (2.27.1)
# Requirement already satisfied: boto3>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (1.26.102)
# Requirement already satisfied: oauthlib>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (3.2.2)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (0.18.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from neptune-client) (1.4.4)
# Requirement already satisfied: swagger-spec-validator>=2.7.4 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (3.0.3)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.35.0 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (1.5.1)
# Requirement already satisfied: bravado<12.0.0,>=11.0.0 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (11.0.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from neptune-client) (23.0)
# Requirement already satisfied: Pillow>=1.1.6 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (8.4.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from neptune-client) (8.1.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from neptune-client) (5.9.4)
# Requirement already satisfied: PyJWT in /usr/local/lib/python3.9/dist-packages (from neptune-client) (2.6.0)
# Requirement already satisfied: botocore<1.30.0,>=1.29.102 in /usr/local/lib/python3.9/dist-packages (from boto3>=1.16.0->neptune-client) (1.29.102)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from boto3>=1.16.0->neptune-client) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from boto3>=1.16.0->neptune-client) (1.0.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.9/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (1.0.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (6.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.9/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (3.18.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (4.5.0)
# Requirement already satisfied: bravado-core>=5.16.1 in /usr/local/lib/python3.9/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (5.17.1)
# Requirement already satisfied: monotonic in /usr/local/lib/python3.9/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (1.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (2.8.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from GitPython>=2.0.8->neptune-client) (4.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20.0->neptune-client) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20.0->neptune-client) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20.0->neptune-client) (2.0.12)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.9/dist-packages (from swagger-spec-validator>=2.7.4->neptune-client) (4.3.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->neptune-client) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas->neptune-client) (1.22.4)
# Requirement already satisfied: jsonref in /usr/local/lib/python3.9/dist-packages (from bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune-client) (1.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->GitPython>=2.0.8->neptune-client) (5.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (0.19.3)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (20.11.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (1.2.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (1.5.1)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (0.1.4)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (1.13)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (2.3)
# Requirement already satisfied: rfc3987 in /usr/local/lib/python3.9/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (1.3.8)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from isoduration->jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (1.2.3)

# %%
# !pip install -e git+https://github.com/awarelab/spinningup_tf2.git#egg=spinup_bis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining spinup_bis from git+https://github.com/awarelab/spinningup_tf2.git#egg=spinup_bis
#   Updating ./src/spinup-bis clone
#   Running command git fetch -q --tags
#   Running command git reset --hard -q 22813011e4ce7a3ceea81fff89953c606192f000
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gym[atari,box2d,classic_control]~=0.15.3 in /usr/local/lib/python3.9/dist-packages (from spinup_bis) (0.15.7)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.9/dist-packages (from spinup_bis) (1.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from spinup_bis) (3.7.1)
# Requirement already satisfied: mpi4py in /usr/local/lib/python3.9/dist-packages (from spinup_bis) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from spinup_bis) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from spinup_bis) (1.4.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from spinup_bis) (1.10.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from spinup_bis) (0.12.2)
# Requirement already satisfied: tensorflow>=2.0 in /usr/local/lib/python3.9/dist-packages (from spinup_bis) (2.11.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from gym[atari,box2d,classic_control]~=0.15.3->spinup_bis) (1.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gym[atari,box2d,classic_control]~=0.15.3->spinup_bis) (1.16.0)
# Requirement already satisfied: cloudpickle~=1.2.0 in /usr/local/lib/python3.9/dist-packages (from gym[atari,box2d,classic_control]~=0.15.3->spinup_bis) (1.2.2)
# Requirement already satisfied: box2d-py~=2.3.5 in /usr/local/lib/python3.9/dist-packages (from gym[atari,box2d,classic_control]~=0.15.3->spinup_bis) (2.3.8)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from gym[atari,box2d,classic_control]~=0.15.3->spinup_bis) (4.7.0.72)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from gym[atari,box2d,classic_control]~=0.15.3->spinup_bis) (8.4.0)
# Requirement already satisfied: atari-py~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from gym[atari,box2d,classic_control]~=0.15.3->spinup_bis) (0.2.9)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (16.0.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (3.19.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (23.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (23.3.3)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (0.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (67.6.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (1.15.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (0.2.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (4.5.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (3.3.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (2.11.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (1.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (1.51.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.0->spinup_bis) (3.8.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.9/dist-packages (from jupyter->spinup_bis) (5.5.6)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.9/dist-packages (from jupyter->spinup_bis) (5.4.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from jupyter->spinup_bis) (6.5.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from jupyter->spinup_bis) (7.7.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.9/dist-packages (from jupyter->spinup_bis) (6.3.0)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.9/dist-packages (from jupyter->spinup_bis) (6.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->spinup_bis) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->spinup_bis) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->spinup_bis) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->spinup_bis) (4.39.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->spinup_bis) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->spinup_bis) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->spinup_bis) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->spinup_bis) (2022.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0->spinup_bis) (0.40.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->spinup_bis) (3.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[atari,box2d,classic_control]~=0.15.3->spinup_bis) (0.18.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (2.16.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (1.8.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter->spinup_bis) (6.1.12)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter->spinup_bis) (7.34.0)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter->spinup_bis) (6.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter->spinup_bis) (0.2.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from ipykernel->jupyter->spinup_bis) (5.7.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->jupyter->spinup_bis) (3.0.6)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->jupyter->spinup_bis) (3.6.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from jupyter-console->jupyter->spinup_bis) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from jupyter-console->jupyter->spinup_bis) (2.14.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (0.4)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (5.8.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (0.7.2)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (2.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (0.7.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (4.9.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (4.11.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (1.5.0)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (5.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (6.0.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->jupyter->spinup_bis) (0.2.2)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->spinup_bis) (0.16.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->spinup_bis) (0.17.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->spinup_bis) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->spinup_bis) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook->jupyter->spinup_bis) (21.3.0)
# Requirement already satisfied: qtpy>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from qtconsole->jupyter->spinup_bis) (2.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->spinup_bis) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->spinup_bis) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->spinup_bis) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->spinup_bis) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->spinup_bis) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=5.0.0->ipykernel->jupyter->spinup_bis) (0.7.5)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.7->nbconvert->jupyter->spinup_bis) (3.2.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (6.1.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat>=5.1->nbconvert->jupyter->spinup_bis) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat>=5.1->nbconvert->jupyter->spinup_bis) (4.3.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->spinup_bis) (0.2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (2.0.12)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.9/dist-packages (from terminado>=0.8.3->notebook->jupyter->spinup_bis) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook->jupyter->spinup_bis) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->jupyter->spinup_bis) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->jupyter->spinup_bis) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter->spinup_bis) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->spinup_bis) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->spinup_bis) (22.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->spinup_bis) (3.2.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->spinup_bis) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->spinup_bis) (2.21)
# Installing collected packages: spinup_bis
#   Attempting uninstall: spinup_bis
#     Found existing installation: spinup-bis 0.1
#     Can't uninstall 'spinup-bis'. No files were found to uninstall.
#   Running setup.py develop for spinup_bis
# Successfully installed spinup_bis-0.1

# %% [markdown]
# # The Code of VPG & PPO

# %%
# If this import fails please restart the runtime
import spinup_bis

# %%
import abc
import random
import time

import numpy as np
import tensorflow as tf

import spinup_bis
from spinup_bis.algos.tf2.vpg import core
from spinup_bis.utils import logx

# %%
class Buffer:
    """A buffer for storing trajectories experienced by a VPG agent.

    Uses Generalized Advantage Estimation (GAE-Lambda) for calculating
    the advantages of state-action pairs.
    """

    def __init__(self, obs_dim, act_dim, size, gamma=0.99, lam=0.95):
        self.obs_buf = np.zeros(core.combined_shape(size, obs_dim),
                                dtype=np.float32)
        self.act_buf = np.zeros(core.combined_shape(size, act_dim),
                                dtype=np.float32)
        self.adv_buf = np.zeros(size, dtype=np.float32)
        self.rew_buf = np.zeros(size, dtype=np.float32)
        self.ret_buf = np.zeros(size, dtype=np.float32)
        self.val_buf = np.zeros(size, dtype=np.float32)
        self.logp_buf = np.zeros(size, dtype=np.float32)
        self.gamma, self.lam = gamma, lam
        self.ptr, self.path_start_idx, self.max_size = 0, 0, size

    def store(self, obs, act, rew, val, logp):
        """Append one timestep of agent-environment interaction to the buffer.
        """
        assert self.ptr < self.max_size  # buffer has to have room
        self.obs_buf[self.ptr] = obs
        self.act_buf[self.ptr] = act
        self.rew_buf[self.ptr] = rew
        self.val_buf[self.ptr] = val
        self.logp_buf[self.ptr] = logp
        self.ptr += 1

    def finish_path(self, last_val=0):
        """Computes reward for unfinished trajectory.

        Call this at the end of a trajectory, or when one gets cut off
        by an epoch ending. This looks back in the buffer to where the
        trajectory started, and uses rewards and value estimates from
        the whole trajectory to compute advantage estimates with GAE-Lambda,
        as well as compute the rewards-to-go for each state, to use as
        the targets for the value function.
        The "last_val" argument should be 0 if the trajectory ended
        because the agent reached a terminal state (died), and otherwise
        should be V(s_T), the value function estimated for the last state.
        This allows us to bootstrap the reward-to-go calculation to account
        for timesteps beyond the arbitrary episode horizon (or epoch cutoff).
        """

        path_slice = slice(self.path_start_idx, self.ptr)
        rews = np.append(self.rew_buf[path_slice], last_val)
        vals = np.append(self.val_buf[path_slice], last_val)

        # the next two lines implement GAE-Lambda advantage calculation
        deltas = rews[:-1] + self.gamma * vals[1:] - vals[:-1]
        self.adv_buf[path_slice] = \
            core.discount_cumsum(deltas, self.gamma * self.lam)

        # the next line computes rewards-to-go, targets for the value function
        self.ret_buf[path_slice] = core.discount_cumsum(rews, self.gamma)[:-1]

        self.path_start_idx = self.ptr

    def get(self):
        """Returns data stored in buffer.

        Call this at the end of an epoch to get all of the data from
        the buffer, with advantages appropriately normalized (shifted to have
        mean zero and std one). Also, resets some pointers in the buffer.
        """
        assert self.ptr == self.max_size  # buffer has to be full
        self.ptr, self.path_start_idx = 0, 0
        # the next two lines implement the advantage normalization trick
        adv_mean, adv_std = self.adv_buf.mean(), self.adv_buf.std()
        self.adv_buf = (self.adv_buf - adv_mean) / adv_std
        return [self.obs_buf, self.act_buf, self.adv_buf,
                self.ret_buf, self.logp_buf]

# %%
class PolicyGradientAlgorithm(abc.ABC):
    def __init__(self, env_fn, actor_critic=core.mlp_actor_critic, ac_kwargs=None, seed=0,
            total_steps=int(1e6), train_every=4000, log_every=4000, gamma=0.99,
            pi_lr=3e-4, v_lr=1e-3, train_v_iters=80, lam=0.97, max_ep_len=1000,
            logger_kwargs=None):
        """Vanilla Policy Gradient with GAE-Lambda for advantage estimation.

        Args:
            env_fn : A function which creates a copy of the environment.
                The environment must satisfy the OpenAI Gym API.

            actor_critic: A function which takes in `action_space` and
                `observation_space` kwargs, and returns actor and critic
                tf.keras.Model-s.

            ac_kwargs (dict): Any kwargs appropriate for the actor_critic
                function you provided to VPG.

            seed (int): Seed for random number generators.

            total_steps (int): Number of environment interactions to run and train
                the agent.

            train_every (int): Number of environment interactions that should elapse
                between training epochs.

            log_every (int): Number of environment interactions that should elapse
                between dumping logs.

            gamma (float): Discount factor. (Always between 0 and 1.)

            pi_lr (float): Learning rate for policy optimizer.

            v_lr (float): Learning rate for value function optimizer.

            train_v_iters (int): Number of gradient descent steps to take on
                value function per epoch.

            lam (float): Lambda for GAE-Lambda. (Always between 0 and 1,
                close to 1.)

            max_ep_len (int): Maximum length of trajectory / episode / rollout.

            logger_kwargs (dict): Keyword args for EpochLogger.
        """
        params_to_save = locals()
        self.logger = logx.EpochLogger(**(logger_kwargs or {}))
        self.logger.save_config(params_to_save)

        random.seed(seed)
        tf.random.set_seed(seed)
        np.random.seed(seed)

        # In case of distributed computations these values have to be updated
        self.total_steps = total_steps
        self.train_every = train_every
        self.log_every = log_every
        self.max_ep_len = max_ep_len
        self.train_v_iters = train_v_iters

        self.env = env_fn()
        obs_dim = np.prod(self.env.observation_space.shape)
        act_dim = self.env.action_space.shape
        self.env.seed(seed)

        self.replay_buffer = Buffer(obs_dim=obs_dim, act_dim=act_dim,
                                size=train_every, gamma=gamma, lam=lam)

        ac_kwargs = ac_kwargs or {}
        ac_kwargs['observation_space'] = self.env.observation_space
        ac_kwargs['action_space'] = self.env.action_space

        self.actor, self.critic = actor_critic(**ac_kwargs)

        self.actor.build(input_shape=(None, obs_dim))
        self.critic.build(input_shape=(None, obs_dim))

        self.actor_optimizer = tf.keras.optimizers.Adam(learning_rate=pi_lr)
        self.critic_optimizer = tf.keras.optimizers.Adam(learning_rate=v_lr)

    @tf.function
    def value(self, observations):
        return self.critic(observations)

    def get_value(self, observation):
        return self.value(np.array([observation])).numpy()[0]

    @tf.function
    def value_loss(self, observations, rtg):
        return tf.reduce_mean((self.critic(observations) - rtg) ** 2)

    @tf.function
    def value_train_step(self, observations, rtg):
        def loss():
            return self.value_loss(observations, rtg)

        self.critic_optimizer.minimize(loss, self.critic.trainable_variables)

        return loss()

    def get_action(self, observation):
        return self.actor.action(np.array([observation])).numpy()[0]

    @tf.function
    def pi_train_step(self, observations, actions, advantages, logp_old):
        def loss():
            logp = self.actor.action_logprob(observations, actions)
            return self.pi_loss(logp, logp_old, advantages)

        self.actor_optimizer.minimize(loss, self.actor.trainable_variables)

        # For logging purposes
        logp = self.actor.action_logprob(observations, actions)
        loss_new = self.pi_loss(logp, logp_old, advantages)

        return loss_new, tf.reduce_mean(logp_old - logp), tf.reduce_mean(-logp)

    def run(self):
        start_time = time.time()
        obs, ep_ret, ep_len = self.env.reset(), 0, 0

        # Main loop: collect experience in env and update/log each epoch
        for t in range(self.total_steps):
            action = self.get_action(obs)
            v_t = self.get_value(obs)
            logp = self.actor.action_logprob(np.array([obs]),
                                        np.array([action])).numpy()[0]

            # Step the env
            new_obs, rew, done, _ = self.env.step(action)
            ep_ret += rew
            ep_len += 1

            # Ignore the "done" signal if it comes from hitting the time
            # horizon (that is, when it's an artificial terminal signal
            # that isn't based on the agent's state)
            done = False if ep_len == self.max_ep_len else done

            # Store experience to replay buffer
            self.replay_buffer.store(obs, action, rew, v_t, logp)
            self.logger.store(VVals=v_t)

            # Super critical, easy to overlook step: make sure to update
            # most recent observation!
            obs = new_obs

            # End of trajectory handling
            if done or (ep_len == self.max_ep_len):
                self.logger.store(EpRet=ep_ret, EpLen=ep_len)

            if done or (ep_len == self.max_ep_len) or (t + 1) % self.train_every == 0:
                obs, ep_ret, ep_len = self.env.reset(), 0, 0

                # if trajectory didn't reach terminal state, bootstrap value target
                last_val = 0 if done else self.get_value(obs)
                self.replay_buffer.finish_path(last_val)

            # Update handling
            if (t + 1) % self.train_every == 0:
                self.do_update()

            # End of epoch wrap-up
            if ((t + 1) % self.log_every == 0) or (t + 1 == self.total_steps):
                # Log info about epoch
                self.logger.log_tabular('EpRet', with_min_and_max=True)
                self.logger.log_tabular('EpLen', average_only=True)
                self.logger.log_tabular('VVals', with_min_and_max=True)
                self.logger.log_tabular('LossV', average_only=True)
                self.logger.log_tabular('LossPi', average_only=True)
                self.logger.log_tabular('Entropy', average_only=True)
                self.logger.log_tabular('KL', average_only=True)
                self.logger.log_tabular('TotalEnvInteracts', (t + 1))
                self.logger.log_tabular('Time', time.time() - start_time)
                self.logger.dump_tabular()

    @abc.abstractmethod
    def do_update(self):
        pass


    @abc.abstractmethod
    def pi_loss(self, logp, advantages):
        pass

# %% [markdown]
# # Exercise
# Please fill in missing pieces of code marked:
# ```
# ###### TODO ######
# <Descritpion>
# #-----------------
#
# ###### END  ######
#
# ```

# %%
class VPG(PolicyGradientAlgorithm):
    def do_update(self):
        [batch_obs, batch_act, batch_adv, batch_rtg,
        batch_logp] = self.replay_buffer.get()

        loss, kl, entropy = self.pi_train_step(batch_obs, batch_act,
                                        batch_adv, batch_logp)
        self.logger.store(LossPi=loss.numpy(), KL=kl.numpy(),
                    Entropy=entropy.numpy())

        for _ in range(self.train_v_iters):
            loss = self.value_train_step(batch_obs, batch_rtg)
            self.logger.store(LossV=loss)

    @tf.function
    def pi_loss(self, logp, _logp_old, advantages):
        ###### TODO ######
        # Implement pi loss calcualation 
        #-----------------
        loss = -tf.reduce_mean(logp * advantages)
        ###### END  ######
        return loss


class PPO(PolicyGradientAlgorithm):
    def __init__(self, clip_ratio=0.2, train_pi_iters=80, target_kl=0.01, **kwargs):
        super(PPO, self).__init__(**kwargs)
        self.clip_ratio = clip_ratio
        self.train_pi_iters = train_pi_iters
        self.target_kl = target_kl

    def do_update(self):
        [batch_obs, batch_act, batch_adv, batch_rtg,
            batch_logp] = self.replay_buffer.get()

        for i in range(self.train_pi_iters):
            loss, kl, entropy = self.pi_train_step(batch_obs, batch_act,
                                                batch_adv, batch_logp)
            self.logger.store(LossPi=loss.numpy(), KL=kl.numpy(),
                            Entropy=entropy.numpy())
            
            ###### TODO ######
            # Implement early stopping of pi training based on kl value
            # Log step at which you break the loop using self.logger.log method
            #-----------------
            if kl > self.target_kl:
                self.logger.log('Early stopping at step {}'.format(i))
                break
            ###### END  ######

        for _ in range(self.train_v_iters):
            loss = self.value_train_step(batch_obs, batch_rtg)
            self.logger.store(LossV=loss)

    @tf.function
    def pi_loss(self, logp, logp_old, advantages):
        ###### TODO ######
        # Implement pi loss calcualation
        #-----------------
        ratio = tf.exp(logp - logp_old)
        clip_ratio = tf.clip_by_value(ratio, 1 - self.clip_ratio, 1 + self.clip_ratio)
        loss = -tf.reduce_mean(tf.minimum(ratio * advantages, clip_ratio * advantages))
        ###### END  ######
        return loss

# %% [markdown]
# # Lets test the solution - train the agents

# %% [markdown]
# ## First sanity check on CartPole
# If your implementation cannot reach the goals specified below you might have some bug in your code.

# %%
import gym

from spinup_bis.algos.tf2.vpg.core import mlp_actor_critic
from spinup_bis import ppo_tf2 as PPO_org

def env_fn():
    env = gym.make("CartPole-v1")
    return env

# %%
# VPG should reach performance over 100 with this setting 
vpg = VPG(env_fn=env_fn, actor_critic=mlp_actor_critic, total_steps=int(5e+4), v_lr=0.001, pi_lr=0.0003, train_every=500, max_ep_len=500, logger_kwargs={"output_dir": "./logs/vpg"})
vpg.run()
# Out:
# Warning: Log dir ./logs/vpg already exists! Storing info there anyway.
# Logging data to ./logs/vpg/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	null,
#     "actor_critic":	"mlp_actor_critic",
#     "env_fn":	"env_fn",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "log_every":	4000,
#     "logger_kwargs":	{
#         "output_dir":	"./logs/vpg"
#     },
#     "max_ep_len":	500,
#     "pi_lr":	0.0003,
#     "seed":	0,
#     "self":	{
#         "<__main__.VPG object at 0x7f502f60f2e0>":	{
#             "logger":	{
#                 "<spinup_bis.utils.logx.EpochLogger object at 0x7f502f60f9d0>":	{
#                     "epoch_dict":	{},
#                     "exp_name":	null,
#                     "first_row":	true,
#                     "log_current_row":	{},
#                     "log_headers":	[],
#                     "neptune_run":	null,
#                     "output_dir":	"./logs/vpg",
#                     "output_file":	{
#                         "<_io.TextIOWrapper name='./logs/vpg/progress.txt' mode='w' encoding='UTF-8'>":	{
#                             "mode":	"w"
#                         }
#                     }
#                 }
#             }
#         }
#     },
#     "total_steps":	50000,
#     "train_every":	500,
#     "train_v_iters":	80,
#     "v_lr":	0.001
# }
# WARNING:tensorflow:`_logp_old` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# ---------------------------------------
# |      AverageEpRet |            29.9 |
# |          StdEpRet |            17.6 |
# |          MaxEpRet |             116 |
# |          MinEpRet |               9 |
# |             EpLen |            29.9 |
# |      AverageVVals |            12.6 |
# |          StdVVals |            6.81 |
# |          MaxVVals |            19.3 |
# |          MinVVals |           -13.1 |
# |             LossV |             193 |
# |            LossPi |         -0.0136 |
# |           Entropy |            0.68 |
# |                KL |       -4.32e-05 |
# | TotalEnvInteracts |           4e+03 |
# |              Time |            20.1 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            32.6 |
# |          StdEpRet |            21.1 |
# |          MaxEpRet |             129 |
# |          MinEpRet |               9 |
# |             EpLen |            32.6 |
# |      AverageVVals |            18.4 |
# |          StdVVals |            6.28 |
# |          MaxVVals |            27.4 |
# |          MinVVals |           -11.5 |
# |             LossV |             173 |
# |            LossPi |         -0.0255 |
# |           Entropy |           0.671 |
# |                KL |        2.86e-05 |
# | TotalEnvInteracts |           8e+03 |
# |              Time |            36.9 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            38.8 |
# |          StdEpRet |              23 |
# |          MaxEpRet |             115 |
# |          MinEpRet |              11 |
# |             EpLen |            38.8 |
# |      AverageVVals |            20.7 |
# |          StdVVals |            8.57 |
# |          MaxVVals |            32.5 |
# |          MinVVals |            1.69 |
# |             LossV |             138 |
# |            LossPi |         -0.0372 |
# |           Entropy |            0.66 |
# |                KL |        4.13e-05 |
# | TotalEnvInteracts |         1.2e+04 |
# |              Time |              54 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |              48 |
# |          StdEpRet |            26.2 |
# |          MaxEpRet |             161 |
# |          MinEpRet |              10 |
# |             EpLen |              48 |
# |      AverageVVals |            25.5 |
# |          StdVVals |            10.6 |
# |          MaxVVals |            38.5 |
# |          MinVVals |            2.67 |
# |             LossV |             165 |
# |            LossPi |         -0.0412 |
# |           Entropy |           0.646 |
# |                KL |       -0.000174 |
# | TotalEnvInteracts |         1.6e+04 |
# |              Time |            71.5 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |              42 |
# |          StdEpRet |            19.9 |
# |          MaxEpRet |             109 |
# |          MinEpRet |              12 |
# |             EpLen |              42 |
# |      AverageVVals |            23.4 |
# |          StdVVals |            11.3 |
# |          MaxVVals |              42 |
# |          MinVVals |            2.75 |
# |             LossV |             135 |
# |            LossPi |         -0.0534 |
# |           Entropy |           0.645 |
# |                KL |        0.000215 |
# | TotalEnvInteracts |           2e+04 |
# |              Time |            88.1 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            50.5 |
# |          StdEpRet |            25.3 |
# |          MaxEpRet |             143 |
# |          MinEpRet |              15 |
# |             EpLen |            50.5 |
# |      AverageVVals |            25.4 |
# |          StdVVals |            12.2 |
# |          MaxVVals |              43 |
# |          MinVVals |           -2.75 |
# |             LossV |             149 |
# |            LossPi |         -0.0411 |
# |           Entropy |           0.639 |
# |                KL |        0.000197 |
# | TotalEnvInteracts |         2.4e+04 |
# |              Time |             105 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            55.6 |
# |          StdEpRet |            26.9 |
# |          MaxEpRet |             145 |
# |          MinEpRet |              21 |
# |             EpLen |            55.6 |
# |      AverageVVals |            28.6 |
# |          StdVVals |            13.2 |
# |          MaxVVals |            46.5 |
# |          MinVVals |          -0.225 |
# |             LossV |             150 |
# |            LossPi |         -0.0307 |
# |           Entropy |           0.626 |
# |                KL |         5.3e-05 |
# | TotalEnvInteracts |         2.8e+04 |
# |              Time |             121 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            59.5 |
# |          StdEpRet |            27.6 |
# |          MaxEpRet |             152 |
# |          MinEpRet |              15 |
# |             EpLen |            59.5 |
# |      AverageVVals |            30.2 |
# |          StdVVals |            14.4 |
# |          MaxVVals |            50.9 |
# |          MinVVals |           0.314 |
# |             LossV |             176 |
# |            LossPi |         -0.0413 |
# |           Entropy |           0.618 |
# |                KL |        9.26e-05 |
# | TotalEnvInteracts |         3.2e+04 |
# |              Time |             138 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            69.8 |
# |          StdEpRet |            40.6 |
# |          MaxEpRet |             205 |
# |          MinEpRet |              15 |
# |             EpLen |            69.8 |
# |      AverageVVals |            31.3 |
# |          StdVVals |            15.4 |
# |          MaxVVals |            54.3 |
# |          MinVVals |           0.526 |
# |             LossV |             187 |
# |            LossPi |         -0.0395 |
# |           Entropy |           0.615 |
# |                KL |        2.27e-05 |
# | TotalEnvInteracts |         3.6e+04 |
# |              Time |             155 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            75.5 |
# |          StdEpRet |            47.9 |
# |          MaxEpRet |             268 |
# |          MinEpRet |              14 |
# |             EpLen |            75.5 |
# |      AverageVVals |            41.4 |
# |          StdVVals |              17 |
# |          MaxVVals |            65.7 |
# |          MinVVals |           0.636 |
# |             LossV |             290 |
# |            LossPi |         -0.0448 |
# |           Entropy |           0.613 |
# |                KL |        4.08e-05 |
# | TotalEnvInteracts |           4e+04 |
# |              Time |             172 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             102 |
# |          StdEpRet |            51.2 |
# |          MaxEpRet |             206 |
# |          MinEpRet |              23 |
# |             EpLen |             102 |
# |      AverageVVals |            43.9 |
# |          StdVVals |            18.8 |
# |          MaxVVals |            66.2 |
# |          MinVVals |          -0.877 |
# |             LossV |             251 |
# |            LossPi |         -0.0419 |
# |           Entropy |           0.611 |
# |                KL |       -8.98e-05 |
# | TotalEnvInteracts |         4.4e+04 |
# |              Time |             189 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             104 |
# |          StdEpRet |            53.6 |
# |          MaxEpRet |             214 |
# |          MinEpRet |              18 |
# |             EpLen |             104 |
# |      AverageVVals |            43.9 |
# |          StdVVals |              18 |
# |          MaxVVals |            68.7 |
# |          MinVVals |           -7.25 |
# |             LossV |             236 |
# |            LossPi |         -0.0308 |
# |           Entropy |           0.606 |
# |                KL |       -2.67e-05 |
# | TotalEnvInteracts |         4.8e+04 |
# |              Time |             205 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             122 |
# |          StdEpRet |            46.5 |
# |          MaxEpRet |             202 |
# |          MinEpRet |              71 |
# |             EpLen |             122 |
# |      AverageVVals |            56.4 |
# |          StdVVals |              17 |
# |          MaxVVals |            74.6 |
# |          MinVVals |            3.03 |
# |             LossV |             348 |
# |            LossPi |         -0.0252 |
# |           Entropy |           0.606 |
# |                KL |       -0.000114 |
# | TotalEnvInteracts |           5e+04 |
# |              Time |             213 |
# ---------------------------------------

# %%
# PPO should reach performance around 500 with this setting
ppo = PPO(env_fn=env_fn, actor_critic=mlp_actor_critic, total_steps=int(5e+4), v_lr=0.001, pi_lr=0.0003, train_every=500, max_ep_len=500, logger_kwargs={"output_dir": "./logs/ppo"})
ppo.run()
# Out:
# Warning: Log dir ./logs/ppo already exists! Storing info there anyway.
# Logging data to ./logs/ppo/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	null,
#     "actor_critic":	"mlp_actor_critic",
#     "env_fn":	"env_fn",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "log_every":	4000,
#     "logger_kwargs":	{
#         "output_dir":	"./logs/ppo"
#     },
#     "max_ep_len":	500,
#     "pi_lr":	0.0003,
#     "seed":	0,
#     "self":	{
#         "<__main__.PPO object at 0x7f50edba54c0>":	{
#             "logger":	{
#                 "<spinup_bis.utils.logx.EpochLogger object at 0x7f50edba5400>":	{
#                     "epoch_dict":	{},
#                     "exp_name":	null,
#                     "first_row":	true,
#                     "log_current_row":	{},
#                     "log_headers":	[],
#                     "neptune_run":	null,
#                     "output_dir":	"./logs/ppo",
#                     "output_file":	{
#                         "<_io.TextIOWrapper name='./logs/ppo/progress.txt' mode='w' encoding='UTF-8'>":	{
#                             "mode":	"w"
#                         }
#                     }
#                 }
#             }
#         }
#     },
#     "total_steps":	50000,
#     "train_every":	500,
#     "train_v_iters":	80,
#     "v_lr":	0.001
# }
# Early stopping at step 9
# Early stopping at step 4
# Early stopping at step 11
# Early stopping at step 14
# Early stopping at step 11
# ---------------------------------------
# |      AverageEpRet |            53.5 |
# |          StdEpRet |            44.7 |
# |          MaxEpRet |             256 |
# |          MinEpRet |               9 |
# |             EpLen |            53.5 |
# |      AverageVVals |            16.6 |
# |          StdVVals |            9.62 |
# |          MaxVVals |              31 |
# |          MinVVals |           -15.7 |
# |             LossV |             545 |
# |            LossPi |         -0.0103 |
# |           Entropy |           0.654 |
# |                KL |         0.00416 |
# | TotalEnvInteracts |           4e+03 |
# |              Time |            21.7 |
# ---------------------------------------
# Early stopping at step 11
# Early stopping at step 21
# Early stopping at step 8
# ---------------------------------------
# |      AverageEpRet |             154 |
# |          StdEpRet |            64.6 |
# |          MaxEpRet |             301 |
# |          MinEpRet |              58 |
# |             EpLen |             154 |
# |      AverageVVals |            41.4 |
# |          StdVVals |            5.47 |
# |          MaxVVals |            50.2 |
# |          MinVVals |            14.4 |
# |             LossV |             648 |
# |            LossPi |        -0.00989 |
# |           Entropy |           0.602 |
# |                KL |         0.00318 |
# | TotalEnvInteracts |           8e+03 |
# |              Time |            39.6 |
# ---------------------------------------
# Early stopping at step 10
# Early stopping at step 5
# Early stopping at step 4
# Early stopping at step 9
# ---------------------------------------
# |      AverageEpRet |             217 |
# |          StdEpRet |            51.2 |
# |          MaxEpRet |             282 |
# |          MinEpRet |              79 |
# |             EpLen |             217 |
# |      AverageVVals |            56.8 |
# |          StdVVals |               3 |
# |          MaxVVals |            60.2 |
# |          MinVVals |            52.3 |
# |             LossV |             618 |
# |            LossPi |        -0.00616 |
# |           Entropy |            0.59 |
# |                KL |         0.00333 |
# | TotalEnvInteracts |         1.2e+04 |
# |              Time |            56.9 |
# ---------------------------------------
# Early stopping at step 4
# Early stopping at step 17
# Early stopping at step 7
# Early stopping at step 3
# ---------------------------------------
# |      AverageEpRet |             197 |
# |          StdEpRet |              77 |
# |          MaxEpRet |             356 |
# |          MinEpRet |              85 |
# |             EpLen |             197 |
# |      AverageVVals |            65.5 |
# |          StdVVals |            2.33 |
# |          MaxVVals |            69.1 |
# |          MinVVals |            61.6 |
# |             LossV |             614 |
# |            LossPi |        -0.00667 |
# |           Entropy |           0.583 |
# |                KL |          0.0011 |
# | TotalEnvInteracts |         1.6e+04 |
# |              Time |            74.4 |
# ---------------------------------------
# Early stopping at step 5
# Early stopping at step 3
# Early stopping at step 15
# Early stopping at step 9
# Early stopping at step 5
# ---------------------------------------
# |      AverageEpRet |             198 |
# |          StdEpRet |            86.5 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             121 |
# |             EpLen |             198 |
# |      AverageVVals |            58.4 |
# |          StdVVals |             8.7 |
# |          MaxVVals |            66.7 |
# |          MinVVals |            10.2 |
# |             LossV |             461 |
# |            LossPi |        -0.00708 |
# |           Entropy |            0.56 |
# |                KL |        0.000234 |
# | TotalEnvInteracts |           2e+04 |
# |              Time |            91.5 |
# ---------------------------------------
# Early stopping at step 13
# ---------------------------------------
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |              84 |
# |          StdVVals |            6.31 |
# |          MaxVVals |              92 |
# |          MinVVals |            72.6 |
# |             LossV |             170 |
# |            LossPi |        -0.00423 |
# |           Entropy |           0.525 |
# |                KL |         0.00167 |
# | TotalEnvInteracts |         2.4e+04 |
# |              Time |             111 |
# ---------------------------------------
# Early stopping at step 4
# ---------------------------------------
# |      AverageEpRet |             445 |
# |          StdEpRet |            83.1 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             245 |
# |             EpLen |             445 |
# |      AverageVVals |            90.2 |
# |          StdVVals |            15.3 |
# |          MaxVVals |            97.1 |
# |          MinVVals |            14.6 |
# |             LossV |             190 |
# |            LossPi |        -0.00702 |
# |           Entropy |           0.555 |
# |                KL |         0.00372 |
# | TotalEnvInteracts |         2.8e+04 |
# |              Time |             129 |
# ---------------------------------------
# Early stopping at step 6
# Early stopping at step 4
# ---------------------------------------
# |      AverageEpRet |             280 |
# |          StdEpRet |             125 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             135 |
# |             EpLen |             280 |
# |      AverageVVals |            77.5 |
# |          StdVVals |            20.5 |
# |          MaxVVals |            92.6 |
# |          MinVVals |            7.46 |
# |             LossV |             186 |
# |            LossPi |         -0.0107 |
# |           Entropy |           0.578 |
# |                KL |         0.00396 |
# | TotalEnvInteracts |         3.2e+04 |
# |              Time |             146 |
# ---------------------------------------
# Early stopping at step 12
# Early stopping at step 46
# Early stopping at step 18
# ---------------------------------------
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            96.4 |
# |          StdVVals |            2.57 |
# |          MaxVVals |            99.1 |
# |          MinVVals |            85.7 |
# |             LossV |            9.24 |
# |            LossPi |        -0.00551 |
# |           Entropy |           0.542 |
# |                KL |         0.00203 |
# | TotalEnvInteracts |         3.6e+04 |
# |              Time |             164 |
# ---------------------------------------
# Early stopping at step 12
# Early stopping at step 13
# Early stopping at step 10
# Early stopping at step 8
# Early stopping at step 18
# ---------------------------------------
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |            99.8 |
# |          StdVVals |           0.208 |
# |          MaxVVals |             100 |
# |          MinVVals |            98.7 |
# |             LossV |          0.0461 |
# |            LossPi |        -0.00505 |
# |           Entropy |           0.508 |
# |                KL |         0.00269 |
# | TotalEnvInteracts |           4e+04 |
# |              Time |             181 |
# ---------------------------------------
# Early stopping at step 7
# Early stopping at step 16
# Early stopping at step 15
# Early stopping at step 14
# Early stopping at step 19
# ---------------------------------------
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |             100 |
# |          StdVVals |         0.00671 |
# |          MaxVVals |             100 |
# |          MinVVals |             100 |
# |             LossV |        4.51e-05 |
# |            LossPi |        -0.00429 |
# |           Entropy |           0.485 |
# |                KL |        0.000889 |
# | TotalEnvInteracts |         4.4e+04 |
# |              Time |             199 |
# ---------------------------------------
# Early stopping at step 5
# Early stopping at step 21
# Early stopping at step 24
# Early stopping at step 11
# Early stopping at step 7
# ---------------------------------------
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |             100 |
# |          StdVVals |         0.00223 |
# |          MaxVVals |             100 |
# |          MinVVals |             100 |
# |             LossV |        7.95e-06 |
# |            LossPi |        -0.00394 |
# |           Entropy |           0.438 |
# |                KL |         0.00236 |
# | TotalEnvInteracts |         4.8e+04 |
# |              Time |             216 |
# ---------------------------------------
# Early stopping at step 8
# Early stopping at step 7
# Early stopping at step 5
# ---------------------------------------
# |      AverageEpRet |             500 |
# |          StdEpRet |               0 |
# |          MaxEpRet |             500 |
# |          MinEpRet |             500 |
# |             EpLen |             500 |
# |      AverageVVals |             100 |
# |          StdVVals |         0.00106 |
# |          MaxVVals |             100 |
# |          MinVVals |             100 |
# |             LossV |        8.78e-06 |
# |            LossPi |        -0.00261 |
# |           Entropy |           0.465 |
# |                KL |        -0.00202 |
# | TotalEnvInteracts |           5e+04 |
# |              Time |             224 |
# ---------------------------------------

# %% [markdown]
# ## Now lets learn more difficult task

# %%
def env_fn():
    env = gym.make("BipedalWalker-v3")
    return env

# %%
vpg = VPG(env_fn=env_fn, actor_critic=mlp_actor_critic, total_steps=int(5e+5), v_lr=0.001, pi_lr=0.0003, train_every=1000, logger_kwargs={"output_dir": "./logs/vpg"})
vpg.run()
# Out:
# Warning: Log dir ./logs/vpg already exists! Storing info there anyway.
# Logging data to ./logs/vpg/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	null,
#     "actor_critic":	"mlp_actor_critic",
#     "env_fn":	"env_fn",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "log_every":	4000,
#     "logger_kwargs":	{
#         "output_dir":	"./logs/vpg"
#     },
#     "max_ep_len":	1000,
#     "pi_lr":	0.0003,
#     "seed":	0,
#     "self":	{
#         "<__main__.VPG object at 0x7f50edd28970>":	{
#             "logger":	{
#                 "<spinup_bis.utils.logx.EpochLogger object at 0x7f50edd28790>":	{
#                     "epoch_dict":	{},
#                     "exp_name":	null,
#                     "first_row":	true,
#                     "log_current_row":	{},
#                     "log_headers":	[],
#                     "neptune_run":	null,
#                     "output_dir":	"./logs/vpg",
#                     "output_file":	{
#                         "<_io.TextIOWrapper name='./logs/vpg/progress.txt' mode='w' encoding='UTF-8'>":	{
#                             "mode":	"w"
#                         }
#                     }
#                 }
#             }
#         }
#     },
#     "total_steps":	500000,
#     "train_every":	1000,
#     "train_v_iters":	80,
#     "v_lr":	0.001
# }
# WARNING:tensorflow:`_logp_old` is not a valid node name. Accepted names conform to Regex /re.compile('^[A-Za-z0-9.][A-Za-z0-9_.\\\\/>-]*$')/
# ---------------------------------------
# |      AverageEpRet |           -66.6 |
# |          StdEpRet |            2.86 |
# |          MaxEpRet |           -61.7 |
# |          MinEpRet |           -68.6 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -4.63 |
# |          StdVVals |            2.82 |
# |          MaxVVals |            0.61 |
# |          MinVVals |           -6.92 |
# |             LossV |            2.24 |
# |            LossPi |          0.0143 |
# |           Entropy |            3.69 |
# |                KL |         0.00475 |
# | TotalEnvInteracts |           4e+03 |
# |              Time |            28.5 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -51.5 |
# |          StdEpRet |            7.01 |
# |          MaxEpRet |           -41.7 |
# |          MinEpRet |           -61.5 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            -5.6 |
# |          StdVVals |           0.647 |
# |          MaxVVals |           -3.21 |
# |          MinVVals |           -6.77 |
# |             LossV |           0.302 |
# |            LossPi |         0.00323 |
# |           Entropy |             3.7 |
# |                KL |         0.00617 |
# | TotalEnvInteracts |           8e+03 |
# |              Time |            46.4 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            -102 |
# |          StdEpRet |            20.8 |
# |          MaxEpRet |           -42.6 |
# |          MinEpRet |            -121 |
# |             EpLen |             328 |
# |      AverageVVals |           -11.1 |
# |          StdVVals |            7.74 |
# |          MaxVVals |            1.23 |
# |          MinVVals |           -20.7 |
# |             LossV |             586 |
# |            LossPi |         -0.0229 |
# |           Entropy |             3.7 |
# |                KL |         0.00135 |
# | TotalEnvInteracts |         1.2e+04 |
# |              Time |            64.5 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            -108 |
# |          StdEpRet |            12.1 |
# |          MaxEpRet |           -70.9 |
# |          MinEpRet |            -116 |
# |             EpLen |             239 |
# |      AverageVVals |           -23.6 |
# |          StdVVals |            2.57 |
# |          MaxVVals |            15.4 |
# |          MinVVals |           -25.6 |
# |             LossV |             703 |
# |            LossPi |          0.0253 |
# |           Entropy |             3.7 |
# |                KL |         0.00081 |
# | TotalEnvInteracts |         1.6e+04 |
# |              Time |            82.8 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -99.9 |
# |          StdEpRet |            19.8 |
# |          MaxEpRet |           -35.3 |
# |          MinEpRet |            -114 |
# |             EpLen |             190 |
# |      AverageVVals |           -20.6 |
# |          StdVVals |            9.79 |
# |          MaxVVals |            3.98 |
# |          MinVVals |             -33 |
# |             LossV |             511 |
# |            LossPi |         -0.0334 |
# |           Entropy |            3.65 |
# |                KL |        0.000941 |
# | TotalEnvInteracts |           2e+04 |
# |              Time |             101 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            -104 |
# |          StdEpRet |            15.7 |
# |          MaxEpRet |           -53.9 |
# |          MinEpRet |            -132 |
# |             EpLen |             188 |
# |      AverageVVals |           -22.9 |
# |          StdVVals |            12.7 |
# |          MaxVVals |            28.4 |
# |          MinVVals |           -39.7 |
# |             LossV |             768 |
# |            LossPi |         0.00655 |
# |           Entropy |            3.64 |
# |                KL |       -0.000201 |
# | TotalEnvInteracts |         2.4e+04 |
# |              Time |             120 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -89.8 |
# |          StdEpRet |            27.6 |
# |          MaxEpRet |           -57.8 |
# |          MinEpRet |            -128 |
# |             EpLen |             458 |
# |      AverageVVals |           -18.2 |
# |          StdVVals |            10.6 |
# |          MaxVVals |           0.335 |
# |          MinVVals |           -39.2 |
# |             LossV |             244 |
# |            LossPi |         -0.0107 |
# |           Entropy |            3.72 |
# |                KL |        0.000202 |
# | TotalEnvInteracts |         2.8e+04 |
# |              Time |             137 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -93.5 |
# |          StdEpRet |              24 |
# |          MaxEpRet |           -52.5 |
# |          MinEpRet |            -123 |
# |             EpLen |             388 |
# |      AverageVVals |           -11.9 |
# |          StdVVals |            6.53 |
# |          MaxVVals |           -3.54 |
# |          MinVVals |           -39.9 |
# |             LossV |             359 |
# |            LossPi |         -0.0177 |
# |           Entropy |            3.68 |
# |                KL |       -2.41e-05 |
# | TotalEnvInteracts |         3.2e+04 |
# |              Time |             155 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -87 |
# |          StdEpRet |            21.9 |
# |          MaxEpRet |           -54.4 |
# |          MinEpRet |            -116 |
# |             EpLen |             470 |
# |      AverageVVals |           -10.5 |
# |          StdVVals |            9.03 |
# |          MaxVVals |           -1.57 |
# |          MinVVals |           -41.6 |
# |             LossV |             182 |
# |            LossPi |           0.021 |
# |           Entropy |            3.63 |
# |                KL |         0.00134 |
# | TotalEnvInteracts |         3.6e+04 |
# |              Time |             172 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            -105 |
# |          StdEpRet |            19.8 |
# |          MaxEpRet |           -55.4 |
# |          MinEpRet |            -134 |
# |             EpLen |             240 |
# |      AverageVVals |           -14.7 |
# |          StdVVals |            11.5 |
# |          MaxVVals |           -1.33 |
# |          MinVVals |           -44.5 |
# |             LossV |             337 |
# |            LossPi |           0.023 |
# |           Entropy |            3.67 |
# |                KL |       -0.000477 |
# | TotalEnvInteracts |           4e+04 |
# |              Time |             190 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -90.5 |
# |          StdEpRet |            22.9 |
# |          MaxEpRet |           -55.8 |
# |          MinEpRet |            -112 |
# |             EpLen |             376 |
# |      AverageVVals |           -11.8 |
# |          StdVVals |            8.68 |
# |          MaxVVals |           -8.17 |
# |          MinVVals |           -46.2 |
# |             LossV |             116 |
# |            LossPi |         0.00498 |
# |           Entropy |            3.64 |
# |                KL |       -0.000357 |
# | TotalEnvInteracts |         4.4e+04 |
# |              Time |             208 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            -107 |
# |          StdEpRet |            14.2 |
# |          MaxEpRet |           -48.2 |
# |          MinEpRet |            -130 |
# |             EpLen |             136 |
# |      AverageVVals |           -41.2 |
# |          StdVVals |            16.6 |
# |          MaxVVals |           -7.33 |
# |          MinVVals |           -55.7 |
# |             LossV |             561 |
# |            LossPi |        -0.00921 |
# |           Entropy |            3.72 |
# |                KL |        0.000539 |
# | TotalEnvInteracts |         4.8e+04 |
# |              Time |             226 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            -106 |
# |          StdEpRet |            17.4 |
# |          MaxEpRet |           -43.5 |
# |          MinEpRet |            -133 |
# |             EpLen |             153 |
# |      AverageVVals |           -23.7 |
# |          StdVVals |              14 |
# |          MaxVVals |           -5.13 |
# |          MinVVals |           -53.9 |
# |             LossV |             558 |
# |            LossPi |          0.0347 |
# |           Entropy |            3.68 |
# |                KL |        -2.5e-05 |
# | TotalEnvInteracts |         5.2e+04 |
# |              Time |             244 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            -107 |
# |          StdEpRet |            7.17 |
# |          MaxEpRet |           -98.3 |
# |          MinEpRet |            -130 |
# |             EpLen |             125 |
# |      AverageVVals |           -36.9 |
# |          StdVVals |            18.5 |
# |          MaxVVals |           -2.71 |
# |          MinVVals |           -59.3 |
# |             LossV |             379 |
# |            LossPi |          0.0407 |
# |           Entropy |             3.7 |
# |                KL |       -0.000105 |
# | TotalEnvInteracts |         5.6e+04 |
# |              Time |             262 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            -106 |
# |          StdEpRet |            25.3 |
# |          MaxEpRet |           -41.7 |
# |          MinEpRet |            -142 |
# |             EpLen |             230 |
# |      AverageVVals |           -29.6 |
# |          StdVVals |            17.1 |
# |          MaxVVals |           -8.27 |
# |          MinVVals |           -60.7 |
# |             LossV |             455 |
# |            LossPi |         -0.0208 |
# |           Entropy |             3.7 |
# |                KL |        0.000726 |
# | TotalEnvInteracts |           6e+04 |
# |              Time |             280 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            -111 |
# |          StdEpRet |            12.3 |
# |          MaxEpRet |            -101 |
# |          MinEpRet |            -149 |
# |             EpLen |             137 |
# |      AverageVVals |           -18.5 |
# |          StdVVals |            20.1 |
# |          MaxVVals |           -2.86 |
# |          MinVVals |             -60 |
# |             LossV |             405 |
# |            LossPi |          0.0236 |
# |           Entropy |            3.65 |
# |                KL |        0.000146 |
# | TotalEnvInteracts |         6.4e+04 |
# |              Time |             298 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            -102 |
# |          StdEpRet |            26.1 |
# |          MaxEpRet |           -39.2 |
# |          MinEpRet |            -121 |
# |             EpLen |             231 |
# |      AverageVVals |           -23.1 |
# |          StdVVals |            17.7 |
# |          MaxVVals |         -0.0786 |
# |          MinVVals |           -58.2 |
# |             LossV |             219 |
# |            LossPi |           0.052 |
# |           Entropy |            3.69 |
# |                KL |        0.000381 |
# | TotalEnvInteracts |         6.8e+04 |
# |              Time |             315 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -78 |
# |          StdEpRet |            30.5 |
# |          MaxEpRet |           -40.8 |
# |          MinEpRet |            -106 |
# |             EpLen |             453 |
# |      AverageVVals |           -8.72 |
# |          StdVVals |            9.85 |
# |          MaxVVals |            2.02 |
# |          MinVVals |             -59 |
# |             LossV |            77.5 |
# |            LossPi |          0.0353 |
# |           Entropy |            3.69 |
# |                KL |         0.00103 |
# | TotalEnvInteracts |         7.2e+04 |
# |              Time |             332 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -48.7 |
# |          StdEpRet |            3.88 |
# |          MaxEpRet |             -43 |
# |          MinEpRet |           -53.9 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -7.17 |
# |          StdVVals |            3.35 |
# |          MaxVVals |           -1.15 |
# |          MinVVals |           -58.5 |
# |             LossV |            17.1 |
# |            LossPi |         0.00364 |
# |           Entropy |            3.69 |
# |                KL |        0.000606 |
# | TotalEnvInteracts |         7.6e+04 |
# |              Time |             350 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -64.7 |
# |          StdEpRet |              29 |
# |          MaxEpRet |           -39.1 |
# |          MinEpRet |            -102 |
# |             EpLen |             628 |
# |      AverageVVals |           -6.56 |
# |          StdVVals |            8.98 |
# |          MaxVVals |            -1.1 |
# |          MinVVals |           -60.5 |
# |             LossV |            67.3 |
# |            LossPi |         -0.0314 |
# |           Entropy |            3.71 |
# |                KL |        0.000926 |
# | TotalEnvInteracts |           8e+04 |
# |              Time |             368 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            -101 |
# |          StdEpRet |            24.1 |
# |          MaxEpRet |           -36.7 |
# |          MinEpRet |            -122 |
# |             EpLen |             189 |
# |      AverageVVals |           -15.6 |
# |          StdVVals |            12.4 |
# |          MaxVVals |           -6.34 |
# |          MinVVals |           -63.7 |
# |             LossV |             274 |
# |            LossPi |         0.00479 |
# |           Entropy |            3.66 |
# |                KL |        0.000664 |
# | TotalEnvInteracts |         8.4e+04 |
# |              Time |             386 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -81.8 |
# |          StdEpRet |            41.1 |
# |          MaxEpRet |           -40.2 |
# |          MinEpRet |            -123 |
# |             EpLen |             547 |
# |      AverageVVals |           -7.66 |
# |          StdVVals |            6.91 |
# |          MaxVVals |           -3.72 |
# |          MinVVals |           -53.8 |
# |             LossV |            88.3 |
# |            LossPi |         0.00728 |
# |           Entropy |            3.68 |
# |                KL |        0.000494 |
# | TotalEnvInteracts |         8.8e+04 |
# |              Time |             403 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -45.1 |
# |          StdEpRet |            2.34 |
# |          MaxEpRet |           -42.9 |
# |          MinEpRet |             -49 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -5.97 |
# |          StdVVals |            1.42 |
# |          MaxVVals |            -5.4 |
# |          MinVVals |           -29.2 |
# |             LossV |            15.1 |
# |            LossPi |         -0.0124 |
# |           Entropy |            3.67 |
# |                KL |         0.00105 |
# | TotalEnvInteracts |         9.2e+04 |
# |              Time |             421 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -66.2 |
# |          StdEpRet |            32.7 |
# |          MaxEpRet |           -35.2 |
# |          MinEpRet |            -107 |
# |             EpLen |             635 |
# |      AverageVVals |           -6.39 |
# |          StdVVals |            4.17 |
# |          MaxVVals |           -4.86 |
# |          MinVVals |           -59.8 |
# |             LossV |            61.3 |
# |            LossPi |         -0.0425 |
# |           Entropy |            3.68 |
# |                KL |       -0.000111 |
# | TotalEnvInteracts |         9.6e+04 |
# |              Time |             439 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -54.9 |
# |          StdEpRet |            28.5 |
# |          MaxEpRet |           -30.2 |
# |          MinEpRet |            -103 |
# |             EpLen |             770 |
# |      AverageVVals |           -5.92 |
# |          StdVVals |            5.38 |
# |          MaxVVals |           -4.52 |
# |          MinVVals |           -65.9 |
# |             LossV |            40.4 |
# |            LossPi |         -0.0064 |
# |           Entropy |            3.66 |
# |                KL |        0.000854 |
# | TotalEnvInteracts |           1e+05 |
# |              Time |             457 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -48.4 |
# |          StdEpRet |            7.17 |
# |          MaxEpRet |           -39.6 |
# |          MinEpRet |           -57.3 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -6.33 |
# |          StdVVals |            1.09 |
# |          MaxVVals |           -5.55 |
# |          MinVVals |           -33.1 |
# |             LossV |            9.31 |
# |            LossPi |         -0.0536 |
# |           Entropy |            3.67 |
# |                KL |        -0.00013 |
# | TotalEnvInteracts |        1.04e+05 |
# |              Time |             474 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -40.5 |
# |          StdEpRet |            6.11 |
# |          MaxEpRet |           -32.2 |
# |          MinEpRet |           -49.4 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -5.26 |
# |          StdVVals |           0.892 |
# |          MaxVVals |           -4.02 |
# |          MinVVals |           -14.3 |
# |             LossV |            3.61 |
# |            LossPi |         -0.0528 |
# |           Entropy |            3.67 |
# |                KL |        6.33e-05 |
# | TotalEnvInteracts |        1.08e+05 |
# |              Time |             492 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -43.2 |
# |          StdEpRet |            5.98 |
# |          MaxEpRet |           -35.8 |
# |          MinEpRet |           -50.2 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -4.52 |
# |          StdVVals |           0.495 |
# |          MaxVVals |           -4.22 |
# |          MinVVals |           -17.4 |
# |             LossV |            2.26 |
# |            LossPi |         -0.0164 |
# |           Entropy |             3.7 |
# |                KL |       -4.34e-05 |
# | TotalEnvInteracts |        1.12e+05 |
# |              Time |             509 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -42.8 |
# |          StdEpRet |            2.27 |
# |          MaxEpRet |           -40.7 |
# |          MinEpRet |           -46.6 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            -4.4 |
# |          StdVVals |           0.346 |
# |          MaxVVals |           -3.92 |
# |          MinVVals |           -10.1 |
# |             LossV |            1.87 |
# |            LossPi |         -0.0428 |
# |           Entropy |            3.69 |
# |                KL |         0.00117 |
# | TotalEnvInteracts |        1.16e+05 |
# |              Time |             527 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -78.3 |
# |          StdEpRet |            37.6 |
# |          MaxEpRet |           -39.9 |
# |          MinEpRet |            -120 |
# |             EpLen |             538 |
# |      AverageVVals |           -7.32 |
# |          StdVVals |            9.93 |
# |          MaxVVals |           -4.26 |
# |          MinVVals |           -60.9 |
# |             LossV |            73.2 |
# |            LossPi |       -0.000295 |
# |           Entropy |            3.68 |
# |                KL |         0.00062 |
# | TotalEnvInteracts |         1.2e+05 |
# |              Time |             545 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -45.7 |
# |          StdEpRet |            1.53 |
# |          MaxEpRet |           -44.2 |
# |          MinEpRet |           -48.3 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -6.35 |
# |          StdVVals |               2 |
# |          MaxVVals |           -4.81 |
# |          MinVVals |           -40.9 |
# |             LossV |            9.64 |
# |            LossPi |          0.0182 |
# |           Entropy |            3.66 |
# |                KL |        0.000821 |
# | TotalEnvInteracts |        1.24e+05 |
# |              Time |             563 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -42.1 |
# |          StdEpRet |             1.6 |
# |          MaxEpRet |           -39.6 |
# |          MinEpRet |             -44 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            -4.5 |
# |          StdVVals |           0.414 |
# |          MaxVVals |           -4.19 |
# |          MinVVals |           -12.5 |
# |             LossV |            1.54 |
# |            LossPi |         -0.0336 |
# |           Entropy |            3.67 |
# |                KL |        7.98e-05 |
# | TotalEnvInteracts |        1.28e+05 |
# |              Time |             580 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -60.3 |
# |          StdEpRet |            31.3 |
# |          MaxEpRet |           -39.8 |
# |          MinEpRet |            -114 |
# |             EpLen |             765 |
# |      AverageVVals |           -4.81 |
# |          StdVVals |            3.97 |
# |          MaxVVals |            -3.8 |
# |          MinVVals |           -62.1 |
# |             LossV |              45 |
# |            LossPi |         -0.0286 |
# |           Entropy |            3.69 |
# |                KL |        0.000298 |
# | TotalEnvInteracts |        1.32e+05 |
# |              Time |             598 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -67.9 |
# |          StdEpRet |            31.6 |
# |          MaxEpRet |           -41.1 |
# |          MinEpRet |            -107 |
# |             EpLen |             632 |
# |      AverageVVals |              -8 |
# |          StdVVals |            5.92 |
# |          MaxVVals |           -2.81 |
# |          MinVVals |           -68.5 |
# |             LossV |              62 |
# |            LossPi |        -0.00504 |
# |           Entropy |            3.68 |
# |                KL |        0.000211 |
# | TotalEnvInteracts |        1.36e+05 |
# |              Time |             616 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -39.7 |
# |          StdEpRet |            3.45 |
# |          MaxEpRet |           -36.2 |
# |          MinEpRet |           -43.9 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -4.85 |
# |          StdVVals |           0.748 |
# |          MaxVVals |           0.388 |
# |          MinVVals |           -9.78 |
# |             LossV |            1.35 |
# |            LossPi |         -0.0342 |
# |           Entropy |            3.69 |
# |                KL |        0.000232 |
# | TotalEnvInteracts |         1.4e+05 |
# |              Time |             633 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -56.1 |
# |          StdEpRet |              28 |
# |          MaxEpRet |           -36.2 |
# |          MinEpRet |            -104 |
# |             EpLen |             765 |
# |      AverageVVals |           -4.57 |
# |          StdVVals |            4.72 |
# |          MaxVVals |          -0.575 |
# |          MinVVals |           -72.2 |
# |             LossV |            19.4 |
# |            LossPi |         -0.0531 |
# |           Entropy |             3.7 |
# |                KL |        0.000395 |
# | TotalEnvInteracts |        1.44e+05 |
# |              Time |             651 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -39.6 |
# |          StdEpRet |            5.27 |
# |          MaxEpRet |           -32.9 |
# |          MinEpRet |           -47.4 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -5.24 |
# |          StdVVals |            1.91 |
# |          MaxVVals |          -0.323 |
# |          MinVVals |           -41.9 |
# |             LossV |            7.49 |
# |            LossPi |          0.0461 |
# |           Entropy |            3.68 |
# |                KL |       -0.000111 |
# | TotalEnvInteracts |        1.48e+05 |
# |              Time |             668 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -55.3 |
# |          StdEpRet |              35 |
# |          MaxEpRet |           -31.2 |
# |          MinEpRet |            -116 |
# |             EpLen |             765 |
# |      AverageVVals |           -5.65 |
# |          StdVVals |            4.12 |
# |          MaxVVals |          -0.335 |
# |          MinVVals |           -65.5 |
# |             LossV |            38.5 |
# |            LossPi |         0.00941 |
# |           Entropy |            3.61 |
# |                KL |        0.000458 |
# | TotalEnvInteracts |        1.52e+05 |
# |              Time |             687 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -54 |
# |          StdEpRet |            30.1 |
# |          MaxEpRet |             -32 |
# |          MinEpRet |            -106 |
# |             EpLen |             766 |
# |      AverageVVals |           -4.35 |
# |          StdVVals |            3.72 |
# |          MaxVVals |          -0.585 |
# |          MinVVals |           -74.6 |
# |             LossV |            13.4 |
# |            LossPi |          -0.048 |
# |           Entropy |            3.64 |
# |                KL |       -0.000183 |
# | TotalEnvInteracts |        1.56e+05 |
# |              Time |             704 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -38.6 |
# |          StdEpRet |            5.58 |
# |          MaxEpRet |           -33.1 |
# |          MinEpRet |           -47.6 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -5.55 |
# |          StdVVals |            5.22 |
# |          MaxVVals |          -0.202 |
# |          MinVVals |           -75.9 |
# |             LossV |            19.3 |
# |            LossPi |         0.00237 |
# |           Entropy |             3.7 |
# |                KL |        9.25e-05 |
# | TotalEnvInteracts |         1.6e+05 |
# |              Time |             722 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -33.4 |
# |          StdEpRet |            4.48 |
# |          MaxEpRet |           -26.2 |
# |          MinEpRet |           -37.7 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.43 |
# |          StdVVals |           0.416 |
# |          MaxVVals |           0.921 |
# |          MinVVals |           -4.86 |
# |             LossV |           0.765 |
# |            LossPi |         -0.0333 |
# |           Entropy |            3.68 |
# |                KL |         0.00161 |
# | TotalEnvInteracts |        1.64e+05 |
# |              Time |             739 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -65.1 |
# |          StdEpRet |            39.6 |
# |          MaxEpRet |           -29.7 |
# |          MinEpRet |            -120 |
# |             EpLen |             628 |
# |      AverageVVals |           -6.49 |
# |          StdVVals |            6.74 |
# |          MaxVVals |           0.107 |
# |          MinVVals |           -75.8 |
# |             LossV |            70.6 |
# |            LossPi |         -0.0195 |
# |           Entropy |            3.66 |
# |                KL |        0.000698 |
# | TotalEnvInteracts |        1.68e+05 |
# |              Time |             757 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -37.7 |
# |          StdEpRet |            1.91 |
# |          MaxEpRet |           -35.7 |
# |          MinEpRet |           -40.7 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -4.45 |
# |          StdVVals |            1.77 |
# |          MaxVVals |           -3.74 |
# |          MinVVals |           -53.9 |
# |             LossV |            2.65 |
# |            LossPi |         0.00507 |
# |           Entropy |            3.66 |
# |                KL |        0.000608 |
# | TotalEnvInteracts |        1.72e+05 |
# |              Time |             775 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -56.3 |
# |          StdEpRet |            28.7 |
# |          MaxEpRet |           -35.7 |
# |          MinEpRet |            -106 |
# |             EpLen |             766 |
# |      AverageVVals |           -5.84 |
# |          StdVVals |            5.62 |
# |          MaxVVals |           -0.65 |
# |          MinVVals |             -78 |
# |             LossV |            34.6 |
# |            LossPi |         -0.0016 |
# |           Entropy |            3.69 |
# |                KL |        0.000599 |
# | TotalEnvInteracts |        1.76e+05 |
# |              Time |             792 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -40 |
# |          StdEpRet |            4.95 |
# |          MaxEpRet |           -32.8 |
# |          MinEpRet |           -44.9 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -4.57 |
# |          StdVVals |           0.779 |
# |          MaxVVals |         -0.0418 |
# |          MinVVals |            -8.1 |
# |             LossV |            1.21 |
# |            LossPi |         -0.0331 |
# |           Entropy |            3.65 |
# |                KL |         0.00025 |
# | TotalEnvInteracts |         1.8e+05 |
# |              Time |             810 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -37.5 |
# |          StdEpRet |            4.31 |
# |          MaxEpRet |           -32.6 |
# |          MinEpRet |           -44.1 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.96 |
# |          StdVVals |            1.27 |
# |          MaxVVals |            4.76 |
# |          MinVVals |           -7.53 |
# |             LossV |           0.346 |
# |            LossPi |          0.0218 |
# |           Entropy |            3.66 |
# |                KL |        0.000113 |
# | TotalEnvInteracts |        1.84e+05 |
# |              Time |             827 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -34.7 |
# |          StdEpRet |            4.17 |
# |          MaxEpRet |           -30.8 |
# |          MinEpRet |           -41.7 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.71 |
# |          StdVVals |            0.78 |
# |          MaxVVals |            1.14 |
# |          MinVVals |           -5.63 |
# |             LossV |           0.587 |
# |            LossPi |         -0.0262 |
# |           Entropy |            3.66 |
# |                KL |        0.000861 |
# | TotalEnvInteracts |        1.88e+05 |
# |              Time |             845 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -72.1 |
# |          StdEpRet |              38 |
# |          MaxEpRet |           -32.8 |
# |          MinEpRet |            -115 |
# |             EpLen |             542 |
# |      AverageVVals |           -7.07 |
# |          StdVVals |            10.8 |
# |          MaxVVals |          -0.769 |
# |          MinVVals |           -79.5 |
# |             LossV |            41.7 |
# |            LossPi |         -0.0333 |
# |           Entropy |            3.68 |
# |                KL |       -0.000313 |
# | TotalEnvInteracts |        1.92e+05 |
# |              Time |             864 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -34 |
# |          StdEpRet |            4.09 |
# |          MaxEpRet |           -31.2 |
# |          MinEpRet |             -41 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.41 |
# |          StdVVals |           0.853 |
# |          MaxVVals |            2.41 |
# |          MinVVals |           -6.69 |
# |             LossV |            1.17 |
# |            LossPi |          0.0101 |
# |           Entropy |            3.62 |
# |                KL |        0.000553 |
# | TotalEnvInteracts |        1.96e+05 |
# |              Time |             881 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -34.6 |
# |          StdEpRet |            4.47 |
# |          MaxEpRet |           -27.6 |
# |          MinEpRet |           -38.8 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.34 |
# |          StdVVals |           0.884 |
# |          MaxVVals |           0.838 |
# |          MinVVals |           -6.85 |
# |             LossV |           0.714 |
# |            LossPi |         -0.0264 |
# |           Entropy |            3.65 |
# |                KL |        0.000162 |
# | TotalEnvInteracts |           2e+05 |
# |              Time |             898 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -34 |
# |          StdEpRet |            1.58 |
# |          MaxEpRet |           -31.9 |
# |          MinEpRet |           -36.3 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.24 |
# |          StdVVals |           0.487 |
# |          MaxVVals |           0.554 |
# |          MinVVals |           -4.42 |
# |             LossV |           0.389 |
# |            LossPi |         -0.0522 |
# |           Entropy |            3.65 |
# |                KL |        0.000528 |
# | TotalEnvInteracts |        2.04e+05 |
# |              Time |             916 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -29 |
# |          StdEpRet |            3.51 |
# |          MaxEpRet |           -23.5 |
# |          MinEpRet |           -33.2 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.05 |
# |          StdVVals |           0.588 |
# |          MaxVVals |            0.96 |
# |          MinVVals |           -3.89 |
# |             LossV |           0.425 |
# |            LossPi |         -0.0467 |
# |           Entropy |            3.69 |
# |                KL |         0.00076 |
# | TotalEnvInteracts |        2.08e+05 |
# |              Time |             934 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -34.7 |
# |          StdEpRet |            3.02 |
# |          MaxEpRet |           -29.9 |
# |          MinEpRet |           -37.7 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.22 |
# |          StdVVals |           0.586 |
# |          MaxVVals |           -0.37 |
# |          MinVVals |           -7.11 |
# |             LossV |           0.649 |
# |            LossPi |         -0.0185 |
# |           Entropy |            3.66 |
# |                KL |         0.00112 |
# | TotalEnvInteracts |        2.12e+05 |
# |              Time |             951 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -68.1 |
# |          StdEpRet |            37.2 |
# |          MaxEpRet |           -24.4 |
# |          MinEpRet |            -107 |
# |             EpLen |             564 |
# |      AverageVVals |           -4.57 |
# |          StdVVals |            8.02 |
# |          MaxVVals |            2.45 |
# |          MinVVals |           -81.2 |
# |             LossV |            28.8 |
# |            LossPi |         0.00869 |
# |           Entropy |            3.69 |
# |                KL |        0.000166 |
# | TotalEnvInteracts |        2.16e+05 |
# |              Time |             969 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -28.5 |
# |          StdEpRet |            3.49 |
# |          MaxEpRet |           -23.5 |
# |          MinEpRet |           -33.4 |
# |             EpLen |           1e+03 |
# |      AverageVVals |              -4 |
# |          StdVVals |            3.05 |
# |          MaxVVals |            1.95 |
# |          MinVVals |           -62.5 |
# |             LossV |            18.8 |
# |            LossPi |         -0.0238 |
# |           Entropy |            3.68 |
# |                KL |       -0.000167 |
# | TotalEnvInteracts |         2.2e+05 |
# |              Time |             986 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -48.5 |
# |          StdEpRet |            35.4 |
# |          MaxEpRet |           -24.9 |
# |          MinEpRet |            -110 |
# |             EpLen |             766 |
# |      AverageVVals |           -5.11 |
# |          StdVVals |            6.85 |
# |          MaxVVals |            2.76 |
# |          MinVVals |           -81.5 |
# |             LossV |            36.1 |
# |            LossPi |        0.000459 |
# |           Entropy |            3.67 |
# |                KL |        0.000104 |
# | TotalEnvInteracts |        2.24e+05 |
# |              Time |           1e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -50.1 |
# |          StdEpRet |            33.5 |
# |          MaxEpRet |           -28.9 |
# |          MinEpRet |            -108 |
# |             EpLen |             764 |
# |      AverageVVals |           -4.78 |
# |          StdVVals |            3.35 |
# |          MaxVVals |            2.74 |
# |          MinVVals |           -64.3 |
# |             LossV |            38.1 |
# |            LossPi |          0.0156 |
# |           Entropy |            3.67 |
# |                KL |        0.000485 |
# | TotalEnvInteracts |        2.28e+05 |
# |              Time |        1.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -32 |
# |          StdEpRet |            4.48 |
# |          MaxEpRet |           -26.6 |
# |          MinEpRet |             -39 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.55 |
# |          StdVVals |             1.1 |
# |          MaxVVals |            4.48 |
# |          MinVVals |           -29.7 |
# |             LossV |            0.92 |
# |            LossPi |         -0.0342 |
# |           Entropy |            3.67 |
# |                KL |        0.000709 |
# | TotalEnvInteracts |        2.32e+05 |
# |              Time |        1.04e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -56.3 |
# |          StdEpRet |            32.3 |
# |          MaxEpRet |           -28.1 |
# |          MinEpRet |            -110 |
# |             EpLen |             769 |
# |      AverageVVals |           -5.02 |
# |          StdVVals |            7.81 |
# |          MaxVVals |            1.49 |
# |          MinVVals |           -83.2 |
# |             LossV |            32.4 |
# |            LossPi |         -0.0564 |
# |           Entropy |            3.68 |
# |                KL |        0.000348 |
# | TotalEnvInteracts |        2.36e+05 |
# |              Time |        1.06e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -48.4 |
# |          StdEpRet |            31.6 |
# |          MaxEpRet |           -23.6 |
# |          MinEpRet |            -102 |
# |             EpLen |             781 |
# |      AverageVVals |           -4.78 |
# |          StdVVals |            6.35 |
# |          MaxVVals |          -0.396 |
# |          MinVVals |           -82.7 |
# |             LossV |            16.3 |
# |            LossPi |         -0.0585 |
# |           Entropy |            3.68 |
# |                KL |        0.000481 |
# | TotalEnvInteracts |         2.4e+05 |
# |              Time |        1.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -69.3 |
# |          StdEpRet |            41.6 |
# |          MaxEpRet |           -25.5 |
# |          MinEpRet |            -118 |
# |             EpLen |             547 |
# |      AverageVVals |           -5.19 |
# |          StdVVals |            8.73 |
# |          MaxVVals |            1.59 |
# |          MinVVals |           -83.9 |
# |             LossV |            25.8 |
# |            LossPi |         0.00929 |
# |           Entropy |            3.65 |
# |                KL |        0.000779 |
# | TotalEnvInteracts |        2.44e+05 |
# |              Time |        1.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -29.4 |
# |          StdEpRet |            3.35 |
# |          MaxEpRet |           -25.4 |
# |          MinEpRet |           -34.2 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.77 |
# |          StdVVals |            1.86 |
# |          MaxVVals |           -2.65 |
# |          MinVVals |           -50.5 |
# |             LossV |             3.3 |
# |            LossPi |           0.058 |
# |           Entropy |            3.62 |
# |                KL |        0.000701 |
# | TotalEnvInteracts |        2.48e+05 |
# |              Time |        1.11e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -29.9 |
# |          StdEpRet |            4.97 |
# |          MaxEpRet |           -23.8 |
# |          MinEpRet |             -36 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -2.91 |
# |          StdVVals |           0.666 |
# |          MaxVVals |           -2.36 |
# |          MinVVals |             -19 |
# |             LossV |            1.86 |
# |            LossPi |         -0.0601 |
# |           Entropy |            3.63 |
# |                KL |       -0.000407 |
# | TotalEnvInteracts |        2.52e+05 |
# |              Time |        1.13e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -91.5 |
# |          StdEpRet |            28.4 |
# |          MaxEpRet |           -35.1 |
# |          MinEpRet |            -111 |
# |             EpLen |             266 |
# |      AverageVVals |            -9.1 |
# |          StdVVals |            15.4 |
# |          MaxVVals |            -2.7 |
# |          MinVVals |           -86.3 |
# |             LossV |            72.1 |
# |            LossPi |        -0.00834 |
# |           Entropy |            3.66 |
# |                KL |       -9.05e-05 |
# | TotalEnvInteracts |        2.56e+05 |
# |              Time |        1.15e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -77.8 |
# |          StdEpRet |              38 |
# |          MaxEpRet |           -31.8 |
# |          MinEpRet |            -119 |
# |             EpLen |             487 |
# |      AverageVVals |           -8.56 |
# |          StdVVals |            11.6 |
# |          MaxVVals |           -4.04 |
# |          MinVVals |             -85 |
# |             LossV |            65.4 |
# |            LossPi |         -0.0388 |
# |           Entropy |            3.64 |
# |                KL |         0.00016 |
# | TotalEnvInteracts |         2.6e+05 |
# |              Time |        1.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -31.6 |
# |          StdEpRet |            1.51 |
# |          MaxEpRet |           -29.4 |
# |          MinEpRet |             -33 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -5.07 |
# |          StdVVals |            2.13 |
# |          MaxVVals |            -3.5 |
# |          MinVVals |             -47 |
# |             LossV |            7.17 |
# |            LossPi |         -0.0412 |
# |           Entropy |            3.62 |
# |                KL |        0.000665 |
# | TotalEnvInteracts |        2.64e+05 |
# |              Time |        1.18e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -33 |
# |          StdEpRet |            2.33 |
# |          MaxEpRet |           -30.6 |
# |          MinEpRet |           -35.4 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.54 |
# |          StdVVals |           0.463 |
# |          MaxVVals |           -3.37 |
# |          MinVVals |           -7.06 |
# |             LossV |             1.9 |
# |            LossPi |        -0.00439 |
# |           Entropy |            3.65 |
# |                KL |         0.00104 |
# | TotalEnvInteracts |        2.68e+05 |
# |              Time |         1.2e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -37.4 |
# |          StdEpRet |            4.14 |
# |          MaxEpRet |           -31.7 |
# |          MinEpRet |           -42.3 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.72 |
# |          StdVVals |           0.655 |
# |          MaxVVals |            1.63 |
# |          MinVVals |           -16.3 |
# |             LossV |            1.48 |
# |            LossPi |         -0.0248 |
# |           Entropy |            3.64 |
# |                KL |        0.000256 |
# | TotalEnvInteracts |        2.72e+05 |
# |              Time |        1.22e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -32.5 |
# |          StdEpRet |            6.97 |
# |          MaxEpRet |           -22.7 |
# |          MinEpRet |           -42.3 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           -3.11 |
# |          StdVVals |           0.863 |
# |          MaxVVals |            1.13 |
# ...
# |          MaxVVals |            11.3 |
# |          MinVVals |           -4.47 |
# |             LossV |            1.31 |
# |            LossPi |         -0.0577 |
# |           Entropy |            3.61 |
# |                KL |        0.000314 |
# | TotalEnvInteracts |        4.08e+05 |
# |              Time |        1.81e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -1.27 |
# |          StdEpRet |            11.8 |
# |          MaxEpRet |            13.6 |
# |          MinEpRet |           -19.4 |
# |             EpLen |           1e+03 |
# |      AverageVVals |          -0.336 |
# |          StdVVals |            1.28 |
# |          MaxVVals |            8.08 |
# |          MinVVals |           -9.47 |
# |             LossV |            2.25 |
# |            LossPi |          0.0145 |
# |           Entropy |            3.61 |
# |                KL |        9.99e-05 |
# | TotalEnvInteracts |        4.12e+05 |
# |              Time |        1.83e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            1.95 |
# |          StdEpRet |            6.68 |
# |          MaxEpRet |            8.63 |
# |          MinEpRet |           -9.16 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           0.429 |
# |          StdVVals |            1.32 |
# |          MaxVVals |             6.8 |
# |          MinVVals |           -11.6 |
# |             LossV |            1.98 |
# |            LossPi |         -0.0474 |
# |           Entropy |            3.65 |
# |                KL |       -0.000332 |
# | TotalEnvInteracts |        4.16e+05 |
# |              Time |        1.84e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             2.8 |
# |          StdEpRet |            7.96 |
# |          MaxEpRet |            10.5 |
# |          MinEpRet |           -8.56 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           0.236 |
# |          StdVVals |            1.17 |
# |          MaxVVals |            7.14 |
# |          MinVVals |           -5.81 |
# |             LossV |            1.98 |
# |            LossPi |         -0.0509 |
# |           Entropy |            3.65 |
# |                KL |        0.000541 |
# | TotalEnvInteracts |         4.2e+05 |
# |              Time |        1.86e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -74.1 |
# |          StdEpRet |            51.3 |
# |          MaxEpRet |            13.7 |
# |          MinEpRet |            -116 |
# |             EpLen |             376 |
# |      AverageVVals |           -5.61 |
# |          StdVVals |            16.5 |
# |          MaxVVals |            6.51 |
# |          MinVVals |           -93.2 |
# |             LossV |            33.2 |
# |            LossPi |         0.00165 |
# |           Entropy |            3.62 |
# |                KL |        0.000131 |
# | TotalEnvInteracts |        4.24e+05 |
# |              Time |        1.88e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -60.9 |
# |          StdEpRet |            54.9 |
# |          MaxEpRet |            16.9 |
# |          MinEpRet |            -108 |
# |             EpLen |             502 |
# |      AverageVVals |           -1.97 |
# |          StdVVals |            14.6 |
# |          MaxVVals |            4.47 |
# |          MinVVals |           -93.6 |
# |             LossV |            56.5 |
# |            LossPi |         0.00877 |
# |           Entropy |            3.62 |
# |                KL |         0.00017 |
# | TotalEnvInteracts |        4.28e+05 |
# |              Time |         1.9e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -10 |
# |          StdEpRet |            46.5 |
# |          MaxEpRet |            17.2 |
# |          MinEpRet |           -90.5 |
# |             EpLen |             960 |
# |      AverageVVals |           -5.56 |
# |          StdVVals |            10.1 |
# |          MaxVVals |            2.53 |
# |          MinVVals |           -78.7 |
# |             LossV |            61.8 |
# |            LossPi |         -0.0459 |
# |           Entropy |            3.61 |
# |                KL |        0.000756 |
# | TotalEnvInteracts |        4.32e+05 |
# |              Time |        1.91e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            20.4 |
# |          StdEpRet |            12.2 |
# |          MaxEpRet |            36.9 |
# |          MinEpRet |            6.56 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            1.87 |
# |          StdVVals |            1.28 |
# |          MaxVVals |            7.66 |
# |          MinVVals |           -5.02 |
# |             LossV |            4.01 |
# |            LossPi |          0.0019 |
# |           Entropy |            3.57 |
# |                KL |        0.000962 |
# | TotalEnvInteracts |        4.36e+05 |
# |              Time |        1.93e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            12.8 |
# |          StdEpRet |            7.24 |
# |          MaxEpRet |            20.9 |
# |          MinEpRet |            2.58 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            1.27 |
# |          StdVVals |             1.1 |
# |          MaxVVals |            6.11 |
# |          MinVVals |           -2.26 |
# |             LossV |            2.77 |
# |            LossPi |         -0.0153 |
# |           Entropy |            3.62 |
# |                KL |        0.000272 |
# | TotalEnvInteracts |         4.4e+05 |
# |              Time |        1.95e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            19.2 |
# |          StdEpRet |            5.89 |
# |          MaxEpRet |            25.8 |
# |          MinEpRet |            9.68 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            1.48 |
# |          StdVVals |           0.982 |
# |          MaxVVals |            6.63 |
# |          MinVVals |           -1.02 |
# |             LossV |            2.81 |
# |            LossPi |         -0.0874 |
# |           Entropy |            3.57 |
# |                KL |        0.000304 |
# | TotalEnvInteracts |        4.44e+05 |
# |              Time |        1.96e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -6.63 |
# |          StdEpRet |            58.5 |
# |          MaxEpRet |            34.3 |
# |          MinEpRet |            -108 |
# |             EpLen |             764 |
# |      AverageVVals |            2.38 |
# |          StdVVals |            6.05 |
# |          MaxVVals |            11.2 |
# |          MinVVals |           -85.3 |
# |             LossV |            12.4 |
# |            LossPi |         -0.0334 |
# |           Entropy |             3.6 |
# |                KL |        2.61e-05 |
# | TotalEnvInteracts |        4.48e+05 |
# |              Time |        1.98e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            11.6 |
# |          StdEpRet |            8.37 |
# |          MaxEpRet |            19.1 |
# |          MinEpRet |            -2.5 |
# |             EpLen |           1e+03 |
# |      AverageVVals |          -0.218 |
# |          StdVVals |            4.41 |
# |          MaxVVals |            1.99 |
# |          MinVVals |           -61.4 |
# |             LossV |            20.5 |
# |            LossPi |         -0.0438 |
# |           Entropy |            3.59 |
# |                KL |         0.00113 |
# | TotalEnvInteracts |        4.52e+05 |
# |              Time |           2e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -56.3 |
# |          StdEpRet |            64.7 |
# |          MaxEpRet |            26.9 |
# |          MinEpRet |            -109 |
# |             EpLen |             552 |
# |      AverageVVals |           -1.55 |
# |          StdVVals |            10.5 |
# |          MaxVVals |            5.69 |
# |          MinVVals |           -93.2 |
# |             LossV |              62 |
# |            LossPi |        -0.00885 |
# |           Entropy |             3.6 |
# |                KL |        0.000688 |
# | TotalEnvInteracts |        4.56e+05 |
# |              Time |        2.02e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -27.8 |
# |          StdEpRet |            60.7 |
# |          MaxEpRet |            38.4 |
# |          MinEpRet |            -109 |
# |             EpLen |             734 |
# |      AverageVVals |            -1.7 |
# |          StdVVals |            11.3 |
# |          MaxVVals |            8.02 |
# |          MinVVals |           -93.7 |
# |             LossV |            59.7 |
# |            LossPi |          -0.031 |
# |           Entropy |            3.59 |
# |                KL |        3.38e-05 |
# | TotalEnvInteracts |         4.6e+05 |
# |              Time |        2.03e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -38 |
# |          StdEpRet |            60.9 |
# |          MaxEpRet |            27.1 |
# |          MinEpRet |            -111 |
# |             EpLen |             710 |
# |      AverageVVals |           -3.86 |
# |          StdVVals |            13.5 |
# |          MaxVVals |            7.52 |
# |          MinVVals |           -92.9 |
# |             LossV |            45.7 |
# |            LossPi |          -0.019 |
# |           Entropy |            3.57 |
# |                KL |        0.000207 |
# | TotalEnvInteracts |        4.64e+05 |
# |              Time |        2.05e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -23.7 |
# |          StdEpRet |            62.3 |
# |          MaxEpRet |            31.3 |
# |          MinEpRet |            -115 |
# |             EpLen |             795 |
# |      AverageVVals |           -2.42 |
# |          StdVVals |            14.4 |
# |          MaxVVals |            7.46 |
# |          MinVVals |             -94 |
# |             LossV |            33.9 |
# |            LossPi |          0.0111 |
# |           Entropy |            3.61 |
# |                KL |        0.000345 |
# | TotalEnvInteracts |        4.68e+05 |
# |              Time |        2.07e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            8.88 |
# |          StdEpRet |            6.44 |
# |          MaxEpRet |            19.3 |
# |          MinEpRet |            1.66 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           0.755 |
# |          StdVVals |            1.11 |
# |          MaxVVals |            7.14 |
# |          MinVVals |           -6.14 |
# |             LossV |            2.14 |
# |            LossPi |         -0.0395 |
# |           Entropy |            3.61 |
# |                KL |         9.9e-05 |
# | TotalEnvInteracts |        4.72e+05 |
# |              Time |        2.09e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |             -12 |
# |          StdEpRet |            52.1 |
# |          MaxEpRet |            27.2 |
# |          MinEpRet |            -102 |
# |             EpLen |             784 |
# |      AverageVVals |          -0.214 |
# |          StdVVals |            9.23 |
# |          MaxVVals |            6.24 |
# |          MinVVals |           -85.9 |
# |             LossV |            13.2 |
# |            LossPi |         0.00816 |
# |           Entropy |            3.58 |
# |                KL |        0.000293 |
# | TotalEnvInteracts |        4.76e+05 |
# |              Time |         2.1e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -45.5 |
# |          StdEpRet |            62.5 |
# |          MaxEpRet |            23.2 |
# |          MinEpRet |            -108 |
# |             EpLen |             530 |
# |      AverageVVals |           -1.08 |
# |          StdVVals |            11.3 |
# |          MaxVVals |            7.81 |
# |          MinVVals |           -94.8 |
# |             LossV |            29.4 |
# |            LossPi |         -0.0146 |
# |           Entropy |            3.62 |
# |                KL |        0.000427 |
# | TotalEnvInteracts |         4.8e+05 |
# |              Time |        2.12e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -55.5 |
# |          StdEpRet |            64.1 |
# |          MaxEpRet |            24.1 |
# |          MinEpRet |            -114 |
# |             EpLen |             619 |
# |      AverageVVals |           -5.74 |
# |          StdVVals |            14.9 |
# |          MaxVVals |            4.87 |
# |          MinVVals |           -94.5 |
# |             LossV |            89.2 |
# |            LossPi |         0.00151 |
# |           Entropy |            3.63 |
# |                KL |        5.52e-05 |
# | TotalEnvInteracts |        4.84e+05 |
# |              Time |        2.14e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            19.1 |
# |          StdEpRet |            7.89 |
# |          MaxEpRet |              32 |
# |          MinEpRet |            11.5 |
# |             EpLen |           1e+03 |
# |      AverageVVals |            1.71 |
# |          StdVVals |           0.763 |
# |          MaxVVals |            2.76 |
# |          MinVVals |           -7.73 |
# |             LossV |            2.34 |
# |            LossPi |         -0.0296 |
# |           Entropy |            3.64 |
# |                KL |        0.000726 |
# | TotalEnvInteracts |        4.88e+05 |
# |              Time |        2.16e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -40.3 |
# |          StdEpRet |              74 |
# |          MaxEpRet |            41.7 |
# |          MinEpRet |            -116 |
# |             EpLen |             541 |
# |      AverageVVals |          -0.116 |
# |          StdVVals |            13.1 |
# |          MaxVVals |            8.18 |
# |          MinVVals |           -95.1 |
# |             LossV |            19.9 |
# |            LossPi |        -0.00524 |
# |           Entropy |            3.59 |
# |                KL |        0.000462 |
# | TotalEnvInteracts |        4.92e+05 |
# |              Time |        2.17e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |           -70.7 |
# |          StdEpRet |            62.7 |
# |          MaxEpRet |            35.4 |
# |          MinEpRet |            -116 |
# |             EpLen |             333 |
# |      AverageVVals |           -4.45 |
# |          StdVVals |              20 |
# |          MaxVVals |            6.21 |
# |          MinVVals |           -94.6 |
# |             LossV |            27.8 |
# |            LossPi |          0.0208 |
# |           Entropy |            3.57 |
# |                KL |       -0.000365 |
# | TotalEnvInteracts |        4.96e+05 |
# |              Time |        2.19e+03 |
# ---------------------------------------
# ---------------------------------------
# |      AverageEpRet |            20.8 |
# |          StdEpRet |            9.44 |
# |          MaxEpRet |            36.7 |
# |          MinEpRet |            11.8 |
# |             EpLen |           1e+03 |
# |      AverageVVals |           0.463 |
# |          StdVVals |            3.08 |
# |          MaxVVals |            7.85 |
# |          MinVVals |           -53.7 |
# |             LossV |            3.79 |
# |            LossPi |        -0.00475 |
# |           Entropy |            3.57 |
# |                KL |        8.74e-05 |
# | TotalEnvInteracts |           5e+05 |
# |              Time |        2.21e+03 |
# ---------------------------------------

# %%
ppo = PPO(env_fn=env_fn, actor_critic=mlp_actor_critic,  total_steps=int(5e+5), v_lr=0.001, pi_lr=0.0003, train_every=1000, logger_kwargs={"output_dir": "./logs/ppo"})
ppo.run()
# Out:
# Warning: Log dir ./logs/ppo already exists! Storing info there anyway.
# Logging data to ./logs/ppo/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	null,
#     "actor_critic":	"mlp_actor_critic",
#     "env_fn":	"env_fn",
#     "gamma":	0.99,
#     "lam":	0.97,
#     "log_every":	4000,
#     "logger_kwargs":	{
#         "output_dir":	"./logs/ppo"
#     },
#     "max_ep_len":	1000,
#     "pi_lr":	0.0003,
#     "seed":	0,
#     "self":	{
#         "<__main__.PPO object at 0x7f50edba5610>":	{
#             "logger":	{
#                 "<spinup_bis.utils.logx.EpochLogger object at 0x7f50edba58b0>":	{
#                     "epoch_dict":	{},
#                     "exp_name":	null,
#                     "first_row":	true,
#                     "log_current_row":	{},
#                     "log_headers":	[],
#                     "neptune_run":	null,
#                     "output_dir":	"./logs/ppo",
#                     "output_file":	{
#                         "<_io.TextIOWrapper name='./logs/ppo/progress.txt' mode='w' encoding='UTF-8'>":	{
#                             "mode":	"w"
#                         }
#                     }
#                 }
#             }
#         }
#     },
#     "total_steps":	500000,
#     "train_every":	1000,
#     "train_v_iters":	80,
#     "v_lr":	0.001
# }

# %% [markdown]
# # Visualize learned policy

# %%
import matplotlib.pyplot as plt
import pandas as pd
from colabgymrender.recorder import Recorder
from pyvirtualdisplay import Display

display = Display(visible=0, size=(400, 300))
display.start()

# %%
def test_agent(actor):
    NUM_TEST_RUNS = 10
    env = gym.make("BipedalWalker-v3")

    performance = []
    for _ in range(NUM_TEST_RUNS):
        done = False
        obs = env.reset()
        ep_reward = 0
        while not done:
            action = actor(tf.expand_dims(obs, axis=0))[0]
            obs, reward, done, info = env.step(action.numpy()[0])
            ep_reward += reward
        performance.append(ep_reward)

    env = gym.make("BipedalWalker-v3")
    env = Recorder(env, "./videos")
    obs = env.reset()
    while True:
        action = actor(tf.expand_dims(obs, axis=0))[0]
        obs, reward, done, info = env.step(action.numpy()[0])

        if done:
            break

    env.release()
    env.play()

    return np.asarray(performance)

# %%
vpg_performance = test_agent(vpg.actor)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-103a53cd7521> in <cell line: 1>()
# ----> 1 vpg_performance = test_agent(vpg.actor)
#
# <ipython-input-11-7dba562fe0e9> in test_agent(actor)
#      25
#      26     env.release()
# ---> 27     env.play()
#      28
#      29     return np.asarray(performance)
#
# /usr/local/lib/python3.9/dist-packages/colabgymrender/recorder.py in play(self)
#      70         filename = 'temp-{start}.mp4'
#      71         clip = VideoFileClip(self.path)
# ---> 72         clip.write_videofile(filename, progress_bar = False, verbose = False)
#      73         display(Video(filename, embed = True))
#      74         os.remove(filename)
#
# TypeError: write_videofile() got an unexpected keyword argument 'progress_bar'

# %%
ppo_performance = test_agent(ppo.actor)

# %% [markdown]
# # Evaluate performance

# %%
vpg_data = pd.read_csv("./logs/vpg/progress.txt", delimiter="\t")
ppo_data = pd.read_csv("./logs/ppo/progress.txt", delimiter="\t")

# %%
plt.plot(vpg_data["AverageEpRet"], label="VPG")
plt.plot(ppo_data["AverageEpRet"], label="PPO")
plt.legend()
plt.show()

# %%
plt.bar(["vpg", "ppo"], [vpg_performance.mean(), ppo_performance.mean()], yerr=[vpg_performance.std(), ppo_performance.std()])
